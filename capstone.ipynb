# %%
# Out:
# <Response [200]>

# %%
import requests
URL="https://www.amazon.in/dp/B0C46HBQ2T/ref=sspa_dk_detail_0?psc=1&pd_rd_i=B0C46HBQ2T&pd_rd_w=ZOldD&content-id=amzn1.sym.dcd65529-2e56-4c74-bf19-15db07b4a1fc&pf_rd_p=dcd65529-2e56-4c74-bf19-15db07b4a1fc&pf_rd_r=HCD6Z7FYTM3T987BEF62&pd_rd_wg=cKl1r&pd_rd_r=3dace772-eee3-4ff3-abaa-b049d7b3fca1&sp_csd=d2lkZ2V0TmFtZT1zcF9kZXRhaWxfdGhlbWF0aWM"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
page=requests.get(URL,headers=headers)
print(page)
# Out:
# <Response [503]>

# %%
import requests
import bs4
URL="https://www.flipkart.com/noise-pro-5-max-1-96-amoled-display-post-workout-analysis-diy-watch-face-bt-calling-smartwatch/p/itm87ff62d6bfe82?pid=SMWGSGQZ9HZPENMN&lid=LSTSMWGSGQZ9HZPENMN7WAQHF&marketplace=FLIPKART&store=ajy%2Fbuh&srno=b_1_1&otracker=browse&fm=organic&iid=en_yme-vfF2UjsF0_1OrrM1WCNhUxXuA1BzaxTY8NRkyPx9fjvEncOL4BnknGUiEcQ4ljg1N-Ewns-6aCSiSsarJA%3D%3D&ppt=None&ppn=None&ssid=s7bzb64pm80000001717000451750"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
page=requests.get(URL,headers=headers)
print(page)
# Out:
# <Response [500]>

# %%
import requests
from bs4 import BeautifulSoup
URL="https://www.amazon.in/dp/B0C46HBQ2T/ref=sspa_dk_detail_0?psc=1&pd_rd_i=B0C46HBQ2T&pd_rd_w=ZOldD&content-id=amzn1.sym.dcd65529-2e56-4c74-bf19-15db07b4a1fc&pf_rd_p=dcd65529-2e56-4c74-bf19-15db07b4a1fc&pf_rd_r=HCD6Z7FYTM3T987BEF62&pd_rd_wg=cKl1r&pd_rd_r=3dace772-eee3-4ff3-abaa-b049d7b3fca1&sp_csd=d2lkZ2V0TmFtZT1zcF9kZXRhaWxfdGhlbWF0aWM"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
page=requests.get(URL,headers=headers)
print(page)
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup
URL="https://www.flipkart.com/noise-pro-5-max-1-96-amoled-display-post-workout-analysis-diy-watch-face-bt-calling-smartwatch/p/itm87ff62d6bfe82?pid=SMWGSGQZ9HZPENMN&lid=LSTSMWGSGQZ9HZPENMN7WAQHF&marketplace=FLIPKART&store=ajy%2Fbuh&srno=b_1_1&otracker=browse&fm=organic&iid=en_yme-vfF2UjsF0_1OrrM1WCNhUxXuA1BzaxTY8NRkyPx9fjvEncOL4BnknGUiEcQ4ljg1N-Ewns-6aCSiSsarJA%3D%3D&ppt=None&ppn=None&ssid=s7bzb64pm80000001717000451750"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
page=requests.get(URL,headers=headers)
print(page)
soup=BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
product_price=soup.find(class_="GURu5w _5V8g3p")

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.flipkart.com/noise-pro-5-max-1-96-amoled-display-post-workout-analysis-diy-watch-face-bt-calling-smartwatch/p/itm87ff62d6bfe82?pid=SMWGSGQZ9HZPENMN&lid=LSTSMWGSGQZ9HZPENMN7WAQHF&marketplace=FLIPKART&store=ajy%2Fbuh&srno=b_1_1&otracker=browse&fm=organic&iid=en_yme-vfF2UjsF0_1OrrM1WCNhUxXuA1BzaxTY8NRkyPx9fjvEncOL4BnknGUiEcQ4ljg1N-Ewns-6aCSiSsarJA%3D%3D&ppt=None&ppn=None&ssid=s7bzb64pm80000001717000451750"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"
}
page = requests.get(URL, headers=headers)
print(page)

soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())

# Find the product price using the correct class attribute
product_price = soup.find(class_="_30jeq3 _16Jk6d")
print(product_price.text)
# Out:
# <Response [500]>
# <html>
#  <body>
#   <h1>
#    500 Internal Server Error
#   </h1>
#   An internal server error occurred.
#  </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c69027c65327> in <cell line: 16>()
#      14 # Find the product price using the correct class attribute
#      15 product_price = soup.find(class_="_30jeq3 _16Jk6d")
# ---> 16 print(product_price.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from bs4 import BeautifulSoup

# URL of the Amazon product page
URL = "https://www.amazon.in/Samsung-Waterfall-sAMOLED-Display-Security/dp/B0C7C28GKF/ref=sr_1_2?crid=3KP5AG6SYGOIT&dib=eyJ2IjoiMSJ9.t5IVx9OHg7yQh9CPhm6h9IGS12BstQUW9B4dAXzxz315sPNWMEpnczg5FurYwLC3cXHSaDN7T4mIYpoM_pAFXD0dbuBdtRcygbEy-XBDupIQHxNEQBhIeZMmwxR-dxXg2AoW-BJYkX2BGc7yOsN9eStRgQNHkjyA1UXnZjPBYrB4Xrmp4fMHB-jRlrjYksE46rwAv184YhCKO7R5DQDVHwSPpZcghcKzw3r9Gyh7A6M.watqLTAICozMo3wCxY2BoFPA6zpaPCG3JVkMObOzCDE&dib_tag=se&keywords=m31&qid=1716997509&sprefix=m3%2Caps%2C905&sr=8-2"

# Custom headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"
}

# Fetch the page content
page = requests.get(URL, headers=headers)

# Print the status code to verify successful request
print(page.status_code)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# Print the parsed HTML for debugging purposes (optional)
print(soup.prettify())

# Try to find the product price element
product_price = soup.find(class_="a-price-whole")

# Check if the product price element exists
if product_price:
    print(product_price.get_text())
else:
    print("Product price not found.")
# Out:
# Streaming output truncated to the last 5000 lines.
#                         },
#                         data: JSON.stringify(dataCart),
#                         xhrFields: {
#                             withCredentials: true
#                         },
#
#                         success: function (responseContent) {
#                             $("#pricingFeedback_thankcontent").innerText = "Success! " + responseContent.toString();
#                             resolve();
#                         },
#
#                         error: function (err) {
#                             $("#pricingFeedback_thankcontent").innerText = "Error! " + err.toString();
#                             reject();
#                         }
#                     })
#             })
#         }
#
#         function getAuthenticationPageURL(asin, hostname) {
# ...

# %%
import requests
from bs4 import BeautifulSoup
URL="https://www.amazon.in/dp/B0C46HBQ2T/ref=sspa_dk_detail_0?psc=1&pd_rd_i=B0C46HBQ2T&pd_rd_w=ZOldD&content-id=amzn1.sym.dcd65529-2e56-4c74-bf19-15db07b4a1fc&pf_rd_p=dcd65529-2e56-4c74-bf19-15db07b4a1fc&pf_rd_r=HCD6Z7FYTM3T987BEF62&pd_rd_wg=cKl1r&pd_rd_r=3dace772-eee3-4ff3-abaa-b049d7b3fca1&sp_csd=d2lkZ2V0TmFtZT1zcF9kZXRhaWxfdGhlbWF0aWM"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
page=requests.get(URL,headers=headers)
print(page)
soup=BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title dir="ltr">
#    Amazon.in
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
#   <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
# ...
